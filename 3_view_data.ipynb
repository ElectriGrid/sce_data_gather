# %% [markdown]
# # Scraping Validation Notebook
#
# This notebook is used to load in and view the data collected from `ica_gather.py` to confirm the completed dataset.

# %%
import geopandas as gpd

sce = gpd.read_file("outputs/ica_circuit_segments.geojson")

# %%
sce.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 667226 entries, 0 to 667225
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   note                          153267 non-null  object
#  1   most_limiting_criteria_pv_of  667226 non-null  object
#  2   circuit_name                  667226 non-null  object
#  3   most_limiting_criteria_pv_sg  667226 non-null  object
#  4   changed_date                  667226 non-null  object
#  5   ica_overall_pv                641355 non-null  float64
#  6   most_limiting_criteria_ug_of  667226 non-null  object
#  7   circuit_voltage               667226 non-null  object
#  8   section_id                    667226 non-null  int64
#  9   uniform_generation_op_flex    642457 non-null  object
#  10  substation_voltage            667226 non-null  object
#  11  substation_name               667226 non-null  object
# ...

# %%
sce.head()
# Out:
#    note most_limiting_criteria_pv_of circuit_name  \
# 0  None      Operational Flexibility        Abana
# 1  None      Operational Flexibility        Abana
# 2  None      Operational Flexibility        Abana
# 3  None      Operational Flexibility        Abana
# 4  None      Operational Flexibility        Abana
#
#   most_limiting_criteria_pv_sg changed_date  ica_overall_pv  \
# 0         Steady State Voltage   01/08/2025             6.0
# 1                      Thermal   01/08/2025             7.0
# 2         Steady State Voltage   01/08/2025             7.0
# 3                      Thermal   01/08/2025             3.0
# 4                      Thermal   01/08/2025             7.0
#
#   most_limiting_criteria_ug_of circuit_voltage  section_id  \
# 0      Operational Flexibility              12    12369095
# 1      Operational Flexibility              12    12368778
# 2      Operational Flexibility              12    12368715
# ...

# %%
# convert geojson to parquet
# sce.to_parquet('outputs/ica_circuit_segments.parquet')
